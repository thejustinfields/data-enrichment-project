# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
movies_2000 = pd.read_csv('Data/final_tmdb_data2000.csv.gz')
movies_2001 = pd.read_csv('Data/final_tmdb_data2001.csv.gz')

# %%
movies_2000.head()
# Out:
#      imdb_id  adult                     backdrop_path  \
# 0          0    NaN                               NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 2  tt0113092    0.0                               NaN
# 3  tt0116391    0.0                               NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
#
#                                belongs_to_collection      budget  \
# 0                                                NaN         NaN
# 1                                                NaN  10000000.0
# 2                                                NaN         0.0
# 3                                                NaN         0.0
# 4  {'id': 1131062, 'name': 'Wong Kar-Wai’s Love T...    150000.0
#
#                                               genres homepage        id  \
# 0                                                NaN      NaN       NaN
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN   62127.0
# ...

# %%
movies_2001.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0035423    0.0  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg                   NaN
# 2  tt0114447    0.0                               NaN                   NaN
# 3  tt0116916    0.0  /rFpHBidSlhjflmnLu7BZilyKeQR.jpg                   NaN
# 4  tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  48000000.0  [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...      NaN
# 2         0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN
# 3         0.0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      NaN
# 4  22000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN
#
# ...

# %%
merged_df = pd.concat([movies_2000, movies_2001], axis = 1, join='inner')

# %%
merged_df.head()
# Out:
#      imdb_id  adult                     backdrop_path  \
# 0          0    NaN                               NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 2  tt0113092    0.0                               NaN
# 3  tt0116391    0.0                               NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
#
#                                belongs_to_collection      budget  \
# 0                                                NaN         NaN
# 1                                                NaN  10000000.0
# 2                                                NaN         0.0
# 3                                                NaN         0.0
# 4  {'id': 1131062, 'name': 'Wong Kar-Wai’s Love T...    150000.0
#
#                                               genres homepage        id  \
# 0                                                NaN      NaN       NaN
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN   62127.0
# ...

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1245 entries, 0 to 1244
# Data columns (total 52 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                1245 non-null   object
#  1   adult                  1244 non-null   float64
#  2   backdrop_path          694 non-null    object
#  3   belongs_to_collection  117 non-null    object
#  4   budget                 1244 non-null   float64
#  5   genres                 1244 non-null   object
#  6   homepage               63 non-null     object
#  7   id                     1244 non-null   float64
#  8   original_language      1244 non-null   object
#  9   original_title         1244 non-null   object
#  10  overview               1223 non-null   object
#  11  popularity             1244 non-null   float64
#  12  poster_path            1127 non-null   object
#  13  production_companies   1244 non-null   object
# ...

# %%
merged_df = merged_df.dropna(subset=["budget"])

# %%
merged_df = merged_df.dropna(subset=["revenue"])

# %%
merged_df['budget'].isna().sum()
# Out:
# budget    0
# budget    0
# dtype: int64

# %%
merged_df['revenue'].isna().sum()
# Out:
# revenue    0
# revenue    0
# dtype: int64

# %%
merged_df['revenue'].describe()
# Out:
#             revenue       revenue
# count  1.244000e+03  1.244000e+03
# mean   1.021681e+07  1.226607e+07
# std    4.522286e+07  6.003824e+07
# min    0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00
# max    5.463881e+08  9.764756e+08
